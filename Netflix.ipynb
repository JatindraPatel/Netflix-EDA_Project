# %% [markdown]
# <a href="https://colab.research.google.com/github/JatindraPatel/Netflix-EDA_Project/blob/main/Netflix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **EDA PROJECT**
# # **NETFLIX - DATASET** :-

# %% [markdown]
#  **This project utilizes the Netflix Titles Dataset which provides a comprehensive catalog of all movies and TV shows available on the Netflix platform. The dataset includes key features such as title, type of content, director, cast, country of production, date_added, release_year, rating, duration, and genre (listed_in). The primary goal is to perform Exploratory Data Analysis (EDA) to uncover trends, distribution patterns, and insights into Netflix's content library**

# %% [markdown]
# # DATA-SET READ

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


df= pd.read_csv('/content/netflix_titles.csv')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # Dataset Details

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe(include='all')
# Out:
#        show_id   type   title       director                cast  \
# count     8807   8807    8807           6173                7982
# unique    8807      2    8807           4528                7692
# top      s8807  Movie  Zubaan  Rajiv Chilaka  David Attenborough
# freq         1   6131       1             19                  19
# mean       NaN    NaN     NaN            NaN                 NaN
# std        NaN    NaN     NaN            NaN                 NaN
# min        NaN    NaN     NaN            NaN                 NaN
# 25%        NaN    NaN     NaN            NaN                 NaN
# 50%        NaN    NaN     NaN            NaN                 NaN
# 75%        NaN    NaN     NaN            NaN                 NaN
# max        NaN    NaN     NaN            NaN                 NaN
#
#               country       date_added  release_year rating  duration  \
# count            7976             8797   8807.000000   8803      8804
# ...

# %% [markdown]
# # **DATA CLEANING** :-

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df['director'] = df['director'].fillna('Not Specified')
df['rating'] = df['rating'].fillna('Not Specified')
df['duration'] = df['duration'].fillna('Not Specified')
df['country'] = df['country'].fillna('Not Specified')
df.dropna(subset=['date_added'], inplace=True)
df['cast'] = df['cast'].fillna('Not Specified')

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water    Not Specified
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans    Not Specified
# 4         s5  TV Show           Kota Factory    Not Specified
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb    Not Specified
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                         Not Specified  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')

# %%
df['added_year'] = df['date_added'].dt.year
df['added_month'] = df['date_added'].dt.strftime('%B')
df['added_day'] = df['date_added'].dt.day

# %%
df['duration'] = df['duration'].str.replace(' min', '').str.replace(' Seasons', '').str.replace(' Season', '')
df['duration'] = pd.to_numeric(df['duration'], errors='coerce')
df.rename(columns={'duration': 'duration_value'}, inplace=True)

# %%
df.columns = [col.capitalize() for col in df.columns]
df.columns
# Out:
# Index(['Show_id', 'Type', 'Title', 'Director', 'Cast', 'Country', 'Date_added',
#        'Release_year', 'Rating', 'Duration_value', 'Listed_in', 'Description',
#        'Added_year', 'Added_month', 'Added_day'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8797 entries, 0 to 8806
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Show_id         8797 non-null   object
#  1   Type            8797 non-null   object
#  2   Title           8797 non-null   object
#  3   Director        8797 non-null   object
#  4   Cast            8797 non-null   object
#  5   Country         8797 non-null   object
#  6   Date_added      8709 non-null   datetime64[ns]
#  7   Release_year    8797 non-null   int64
#  8   Rating          8797 non-null   object
#  9   Duration_value  8794 non-null   float64
#  10  Listed_in       8797 non-null   object
#  11  Description     8797 non-null   object
#  12  Added_year      8709 non-null   float64
#  13  Added_month     8709 non-null   object
#  14  Added_day       8709 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(10)
# memory usage: 1.1+ MB

# %%
valid_ratings = [
    "TV-MA","TV-14","TV-PG","R","PG-13","TV-Y","TV-Y7","PG","TV-G","NR","G",
    "TV-Y7-FV","NC-17","UR","Not Specified"
]

df_clean = df[df['Rating'].isin(valid_ratings)]

# %%
df.columns = [col.capitalize() for col in df.columns]

# %% [markdown]
# # DATA - Analysis :-

# %% [markdown]
# 1.	 WAP to get the shape {row & column} of the dataset....?
# 2.	 WAP to get the first 10 rows of a dataset...?
# 3.	 WAP to get the last 10 rows of a dataset...?
# 4.	 WAP to get the list of all the moives from the Dataset...?
# 5.	 WAP to get the list of all the TV shows from the Dataset...?
# 6.	 WAP to get how many movies are release in each county...?
# 7.	 WAP to get how many TV Show are release in each county...?
# 8.	 WAP to get which moive and the TV show is release in India...?
# 9.	 WAP to get which year has the highest number of releases (Movies + TV Shows)...?
# 10.	 WAP to get which year has the smallest number of releases (Movies + TV Shows)...?
# 11.	 WAP to get the which director has the maximum Movies on Netflix?
# 12.	 WAP to get the which director has the minimum Movies on Netflix?
# 13.	 WAP to getTop 10 countries with the most content on Netflix.
# 14.	 WAP to getCount of Movies and TV Shows by rating (TV-MA, TV-14, R, PG, etc.).
# 15.	 WAP to get Top 10 actors/actresses with most appearances.
# 16.	 WAP to get Find the oldest Movie in the dataset.
# 17.	 WAP to get Find the oldest TV Show in the dataset.
# 18.	 WAP to get How many content pieces were added to Netflix after 2020?
# 19.	 WAP to get Which Movie has the longest duration?
# 20.	 WAP to getWhich TV Show has the most seasons?

# %%
1. # WAP to get the shape {row & column} of the dataset....?

df.shape
# Out:
# (8797, 15)

# %%
2. # WAP to get the first 10 rows of a dataset...?
df.head(10)
# Out:
#   Show_id     Type                             Title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         Director  \
# 0                Kirsten Johnson
# 1                  Not Specified
# 2                Julien Leclercq
# 3                  Not Specified
# 4                  Not Specified
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
3. # WAP to get the last 10 rows of a dataset...?

df.tail(10)
# Out:
#      Show_id     Type               Title                 Director  \
# 8797   s8798  TV Show           Zak Storm            Not Specified
# 8798   s8799    Movie            Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie               Zenda           Avadhoot Gupte
# 8800   s8801  TV Show  Zindagi Gulzar Hai            Not Specified
# 8801   s8802    Movie             Zinzana          Majid Al Ansari
# 8802   s8803    Movie              Zodiac            David Fincher
# 8803   s8804  TV Show         Zombie Dumb            Not Specified
# 8804   s8805    Movie          Zombieland          Ruben Fleischer
# 8805   s8806    Movie                Zoom             Peter Hewitt
# 8806   s8807    Movie              Zubaan              Mozez Singh
#
#                                                    Cast  \
# 8797  Michael Johnston, Jessica Gee-George, Christin...
# 8798  Adil Hussain, Mona Singh, K.K. Raina, Sanjay M...
# 8799  Santosh Juvekar, Siddharth Chandekar, Sachit P...
# ...

# %%
4. # WAP to get the list of all the moives from the Dataset...?
df[df['Type']=='Movie']
# Out:
#      Show_id   Type                             Title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            Director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
5. # WAP to get the list of all the TV shows from the Dataset...?

df[df['Type']=='TV Show']
# Out:
#      Show_id     Type                  Title         Director  \
# 1         s2  TV Show          Blood & Water    Not Specified
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans    Not Specified
# 4         s5  TV Show           Kota Factory    Not Specified
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V    Not Specified
# 8796   s8797  TV Show             Yunus Emre    Not Specified
# 8797   s8798  TV Show              Zak Storm    Not Specified
# 8800   s8801  TV Show     Zindagi Gulzar Hai    Not Specified
# 8803   s8804  TV Show            Zombie Dumb    Not Specified
#
#                                                    Cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
6. # WAP to get how many movies are release in each county...?

df[df['Type']=='Movie']['Country'].value_counts()
# Out:
# Country
# United States                                             2058
# India                                                      893
# Not Specified                                              440
# United Kingdom                                             206
# Canada                                                     122
#                                                           ...
# Germany, Canada, United States                               1
# Denmark, United Kingdom, South Africa, Sweden, Belgium       1
# Serbia, South Korea, Slovenia                                1
# United Kingdom, Spain, Belgium                               1
# United States, Canada, Japan, Panama                         1
# Name: count, Length: 652, dtype: int64

# %%
7. # WAP to get how many tv shows are release in each county...?

df[df['Type']=='TV Show']['Country'].value_counts()
# Out:
# Country
# United States                                     754
# Not Specified                                     390
# United Kingdom                                    212
# Japan                                             168
# South Korea                                       158
#                                                  ...
# Ireland, Canada, United States, United Kingdom      1
# Germany, United States, Italy                       1
# United Kingdom, United States, Czech Republic       1
# Japan, Canada                                       1
# United States, France, South Korea, Indonesia       1
# Name: count, Length: 197, dtype: int64

# %%
8. # WAP to get which moive and the TV show is release in India...?

df[df['Country']=='India']
# Out:
#      Show_id     Type                          Title                 Director  \
# 4         s5  TV Show                   Kota Factory            Not Specified
# 24       s25    Movie                          Jeans               S. Shankar
# 39       s40  TV Show                   Chhota Bheem            Not Specified
# 50       s51  TV Show                  Dharmakshetra            Not Specified
# 66       s67  TV Show  Raja Rasoi Aur Anya Kahaniyan            Not Specified
# ...      ...      ...                            ...                      ...
# 8773   s8774    Movie            Yanda Kartavya Aahe             Kedar Shinde
# 8775   s8776  TV Show                Yeh Meri Family            Not Specified
# 8798   s8799    Movie                       Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie                          Zenda           Avadhoot Gupte
# 8806   s8807    Movie                         Zubaan              Mozez Singh
#
# ...

# %%
9. # WAP to get which year has the highest number of releases (Movies + TV Shows)...?
df['Release_year'].value_counts().idxmax()
# Out:
# np.int64(2018)

# %%
10. # WAP to get which year has the smallest number of releases (Movies + TV Shows)...?

df['Release_year'].value_counts().idxmin()
# Out:
# np.int64(1961)

# %%
11. # WAP to get the which director has the maximum Movies on Netflix?

df[df['Director'] != 'Not Specified']['Director'].value_counts().idxmax()

# because we fill null value by Not Specified at the time of data cleaning that is why we use != 'Not Specified'
# Out:
# 'Rajiv Chilaka'

# %%
12. # WAP to get the which director has the minimum Movies on Netflix?

df[df['Type']=='Movie']['Director'].value_counts().idxmin()
# Out:
# 'Amman Abbasi'

# %%
13. #	WAP to get which TV Show has the most seasons?

df.loc[df[df['Type'] == 'TV Show']['Duration_value'].idxmax(),'Title']
# Out:
# "Grey's Anatomy"

# %%
14. #	WAP to get which Movie has the longest duration?

df.loc[df[df['Type'] == 'Movie']['Duration_value'].idxmax(),'Title']
# Out:
# 'Black Mirror: Bandersnatch'

# %%
15. # WAP to get how many content pieces were added to Netflix after 2020?

df[df['Release_year'] > 2020]['Release_year'].count()
# Out:
# np.int64(592)

# %%
16. # WAP to get count of Movies and TV Shows by rating (TV-MA, TV-14, R, PG, etc.)..?

df.groupby('Type')['Rating'].value_counts()
# Out:
# Type     Rating
# Movie    TV-MA            2062
#          TV-14            1427
#          R                 797
#          TV-PG             540
#          PG-13             490
#          PG                287
#          TV-Y7             139
#          TV-Y              131
#          TV-G              126
#          NR                 75
#          G                  41
#          TV-Y7-FV            5
#          NC-17               3
#          UR                  3
#          Not Specified       2
#          66 min              1
#          74 min              1
#          84 min              1
# TV Show  TV-MA            1143
#          TV-14             730
#          TV-PG             321
#          TV-Y7             194
#          TV-Y              175
#          TV-G               94
#          NR                  4
#          Not Specified       2
#          R                   2
#          TV-Y7-FV            1
# Name: count, dtype: int64

# %%
17. # WAP to get find the oldest Movie in the dataset...?

df.loc[df[df['Type'] == 'Movie']['Release_year'].idxmin(),'Title']
# Out:
# 'Prelude to War'

# %%
18. # WAP to get find the oldest TV Show in the dataset...?


df.loc[df[df['Type'] == 'TV Show']['Release_year'].idxmin(),'Title']
# Out:
# 'Pioneers: First Women Filmmakers*'

# %%
19. # WAP to get Top 10 countries with the most content on Netflix...?

df['Country'].value_counts().head(10)
# Out:
# Country
# United States     2812
# India              972
# Not Specified      830
# United Kingdom     418
# Japan              244
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Name: count, dtype: int64

# %%
20. # WAP to get Top 10 actors/actresses with most appearances....?

df[df['Cast'] != 'Not Specified']['Cast'].value_counts().head(10)
# Out:
# Cast
# David Attenborough                                                                                                        19
# Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jigna Bhardwaj, Rajesh Kava, Mousam, Swapnil                                   14
# Samuel West                                                                                                               10
# Jeff Dunham                                                                                                                7
# David Spade, London Hughes, Fortune Feimster                                                                               6
# Kevin Hart                                                                                                                 6
# Craig Sechler                                                                                                              6
# ...

# %% [markdown]
# # **DATA - Visualization** :-

# %%
# Count of movies and tv show by using pie chart...?

import matplotlib.pyplot as plt
import seaborn as sns

colors = sns.color_palette("bright")
df['Type'].value_counts().plot(kind='pie', autopct='%2.1f%%', startangle=90, colors=colors)
plt.title('Count of Movies and TV Shows',fontweight='bold')
plt.ylabel('')
plt.show()

# %%
# WAP to plot Top 10 Movies on Netflix using a bar chart...?

import matplotlib.pyplot as plt
import seaborn as sns

Movie = df[df['Type'] == 'Movie']['Title'].value_counts().head(10)
plt.figure(figsize=(10,5))
sns.barplot(x=Movie.index, y=Movie.values, palette="bright", hue=Movie.index, legend=False)
plt.title('Top 10 Movie on Netflix ', fontsize=18, fontweight='bold')
plt.xlabel('Movie Titles', fontsize=14)
plt.ylabel('Total Count', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=12)
plt.show()
# Out:
# /tmp/ipython-input-2219494524.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(fontsize=12)

# %%
# WAP to plot Top 10 Tv show on Netflix using a bar chart...?
import matplotlib.pyplot as plt
import seaborn as sns

TV = df[df['Type'] == 'TV Show']['Title'].value_counts().head(10)

sns.barplot(x=TV.index, y=TV.values, palette="Set1", hue=TV.index, legend=False)
plt.title('Top 10 TV Shows on Netflix ', fontsize=18, fontweight='bold')
plt.xlabel('TV Show Titles', fontsize=14)
plt.ylabel('Total Count', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=12)
plt.show()
# Out:
# /tmp/ipython-input-1895778519.py:13: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(fontsize=12)

# %%
# WAP to find out the Year-wise trend of content added using a line chart...?

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid")

year_counts = df['Release_year'].value_counts().sort_index()
plt.figure(figsize=(10, 6))
sns.lineplot(x=year_counts.index, y=year_counts.values, marker='o')
plt.title('Year-wise Trend of Content Added', fontsize=16, fontweight='bold')
plt.xlabel('Year', fontsize=14)
plt.ylabel('Count', fontsize=14)


plt.show()

# %%
# WAP to plot the distribution of content ratings (TV-MA, TV-14, PG, etc.) using a bar chart...?

import matplotlib.pyplot as plt
import seaborn as sns

df_clean['Rating'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Distribution of Content Ratings', fontsize=16, fontweight='bold')
plt.xlabel('Rating', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.9)
plt.show()

# %%
# WAP to plot Movies vs TV Shows Added per Year..?

import matplotlib.pyplot as plt
import seaborn as sns

df.groupby(['Added_year','Type']).size().unstack().plot(kind='line')
plt.title('Movie vs TV Shows Added Per Year', fontsize=16, fontweight='bold')
plt.show()

# %%
# WAP to plot Movies vs TV Shows Added per Month..?

import matplotlib.pyplot as plt
import seaborn as sns

df.groupby(['Added_month','Type']).size().unstack().plot(kind='line')
plt.title('Movie vs TV Shows Added Per Month', fontsize=16, fontweight='bold')
plt.show()

# %%
# WAP to plot Top 10 countries producing the highest number of Netflix titles using a bar chart.....?

import matplotlib.pyplot as plt
import seaborn as sns

top = df[df['Country'] != 'Not Specified']['Country'].value_counts().head(10).reset_index()
top.columns = ['Country', 'Count']
sns.barplot(data=top, x='Country', y='Count', palette="bright")

plt.title('Top 10 Netflix Title Producing Countries', fontsize=18, fontweight='bold')
plt.xlabel('Country', fontsize=14)
plt.ylabel('Count of Titles', fontsize=14)
plt.xticks(rotation=40, ha='right')
plt.show()
# Out:
# /tmp/ipython-input-2927226873.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top, x='Country', y='Count', palette="bright")

# %%
# WAP to plot Top 10 directors producing the highest number of Netflix titles using a bar chart.....?

import matplotlib.pyplot as plt
import seaborn as sns

top = df[df['Director'] != 'Not Specified']['Director'].value_counts().head(10).reset_index()
top.columns = ['Director', 'Count']
sns.barplot(data=top, x='Director', y='Count', palette="bright")

plt.title('Top 10 Netflix Title Producing Directors', fontsize=18, fontweight='bold')
plt.xlabel('Directors', fontsize=14)
plt.ylabel('Count of Titles', fontsize=14)
plt.xticks(rotation=40, ha='right')
plt.show()
# Out:
# /tmp/ipython-input-2116224822.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top, x='Director', y='Count', palette="bright")

# %%
# WAP to plot Top 10 Actors using a bar chart.....?

import matplotlib.pyplot as plt
import seaborn as sns
